# %%
import EWMA_QuantTree as ew
import qtLibrary.libquanttree as qt
import auxiliary_project_functions as au
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re

# %% [markdown]
# <p><strong> Online EWMA </strong><7p>
# <p> Receive trainign set
# <p>

# %%
plt.plot([0.33499999999999996, 0.36824999999999997, 0.39983749999999996, 0.42984562499999995, 0.41762803124999986, 0.4425669265624999, 0.4317495333593749, 0.4537261035664061, 0.4456125268236326, 0.43615878567776345, 0.44715474391330884, 0.44072527296329744, 0.4427334258520203, 0.44541184825659763, 0.44233470233973793, 0.4456735435744887, 0.44527594033636636, 0.442155133739034, 0.4416473171942536, 0.4412756808232413, 0.4383050459649128, 0.43868695892855003, 0.44211573477041977, 0.44594352251136377, 0.43766217948663455, 0.4337193253888465, 0.4352528966583439, 0.43294235977744866, 0.43431266783576217, 0.4279675691963972, 0.4266223628521672, 0.41793364130894206])
plt.title('EWMA thresholds')
plt.show()
